# %%
# %run main_VAE.py -nf 10
# Out:
# MODEL SETTINGS:
#  Namespace(batch_size=100, cuda=True, dataset='mnist', decoder_dim=256, early_stopping_epochs=100, encoder_dim=256, epochs=1000, flow='planar', gpu_num=0, learning_rate=0.0005, log_interval=10, manual_seed=7258, max_beta=1.0, min_beta=0.0, no_cuda=False, num_flows=10, out_dir='snapshots', testing=True, warmup=100, z_size=64)
#
# Random Seed:  7258
# Model on GPU
# PlanarVAE(
#   (encoder): MLP(
#     (first): Linear(in_features=784, out_features=256, bias=True)
#     (layers): ModuleList(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=256, bias=True)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (last): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (decoder): MLP(
#     (first): Linear(in_features=64, out_features=256, bias=True)
#     (layers): ModuleList(
#       (0): Linear(in_features=256, out_features=256, bias=True)
# ...

# %%
# %run main_VAE.py -nf 4
# Out:
# MODEL SETTINGS:
#  Namespace(batch_size=100, cuda=True, dataset='mnist', decoder_dim=256, early_stopping_epochs=100, encoder_dim=256, epochs=1000, flow='planar', gpu_num=0, learning_rate=0.0005, log_interval=10, manual_seed=7258, max_beta=1.0, min_beta=0.0, no_cuda=False, num_flows=4, out_dir='snapshots', testing=True, warmup=100, z_size=64)
#
# Random Seed:  7258
# Model on GPU
# PlanarVAE(
#   (encoder): MLP(
#     (first): Linear(in_features=784, out_features=256, bias=True)
#     (layers): ModuleList(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=256, bias=True)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (last): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (decoder): MLP(
#     (first): Linear(in_features=64, out_features=256, bias=True)
#     (layers): ModuleList(
#       (0): Linear(in_features=256, out_features=256, bias=True)
# ...
